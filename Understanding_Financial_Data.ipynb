# %% [markdown]
# <a href="https://colab.research.google.com/github/RANJEETH-RIKKALA/FINANCIAL_ENGINEERING_WITH_AI/blob/DEV_RIKKALA_1.28.2026/Understanding_Financial_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Downloading Data

# %%
# !wget -nc https://lazyprogrammer.me/course_files/all_stocks_5yr.csv
# Out:
# --2026-01-28 18:50:26--  https://lazyprogrammer.me/course_files/all_stocks_5yr.csv
# Resolving lazyprogrammer.me (lazyprogrammer.me)... 104.21.23.210, 172.67.213.166, 2606:4700:3030::ac43:d5a6, ...
# Connecting to lazyprogrammer.me (lazyprogrammer.me)|104.21.23.210|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 29580549 (28M) [text/csv]
# Saving to: ‘all_stocks_5yr.csv’
#
# all_stocks_5yr.csv  100%[===================>]  28.21M  46.1MB/s    in 0.6s
#
# 2026-01-28 18:50:27 (46.1 MB/s) - ‘all_stocks_5yr.csv’ saved [29580549/29580549]
