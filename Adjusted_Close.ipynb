# %% [markdown]
# <a href="https://colab.research.google.com/github/RANJEETH-RIKKALA/FINANCIAL_ENGINEERING_WITH_AI/blob/DEV_RIKKALA_1.28.2026/Adjusted_Close.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
